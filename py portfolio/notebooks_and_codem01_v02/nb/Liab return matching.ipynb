# %%
#Calculate begining balance and weigths of bonds for series of liab
import pandas as pd
import numpy as np
import scipy as sc
import erdm_risk_kit_basic as risk
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Liab in years
liab_cf = pd.Series(data=[-10**6, -2*10**6, -3*10**6], index=[3, 5, 10])
#Bonds Assests
bond_1 = {'face_value': 1000, 'coupon_rate':0.05, 'maturity': 15, 'coupons_per_year':2}
bond_2 = {'face_value': 1000, 'coupon_rate':0.06, 'maturity': 5, 'coupons_per_year':4}
discount_rate = 0.05
b1_cf = risk.bond_cash_flows_monthly(maturity=bond_1['maturity'], principal=bond_1['face_value'], coupon_rate=bond_1['coupon_rate'], coupons_per_year=bond_1['coupons_per_year'])
b2_cf = risk.bond_cash_flows_monthly(maturity=bond_2['maturity'], principal=bond_2['face_value'], coupon_rate=bond_2['coupon_rate'], coupons_per_year=bond_2['coupons_per_year'])
b1_cf_orig = risk.bond_cash_flows(maturity=bond_1['maturity'], principal=bond_1['face_value'], coupon_rate=bond_1['coupon_rate'], coupons_per_year=bond_1['coupons_per_year'])

mduration_1 = risk.macaulay_duration(b1_cf, discount_rate/bond_1['coupons_per_year'])/bond_1['coupons_per_year']
dur_1_orig = risk.macaulay_duration(b1_cf_orig, discount_rate/bond_1['coupons_per_year'])/bond_1['coupons_per_year']

# %%
(mduration_1, dur_1_orig, discount_rate)
# Out:
# (25.603740622884217, 10.72677495379012, 0.05)

# %%
risk.discount(b1_cf.index, 0.05/12)
# Out:
#             0
# 0    1.000000
# 6    0.975361
# 12   0.951328
# 18   0.927888
# 24   0.905025
# 30   0.882726
# 36   0.860976
# 42   0.839762
# 48   0.819071
# 54   0.798890
# 60   0.779205
# 66   0.760006
# 72   0.741280
# 78   0.723015
# 84   0.705201
# 90   0.687825
# 96   0.670877
# 102  0.654347
# 108  0.638225
# 114  0.622499
# 120  0.607161
# 126  0.592201
# 132  0.577609
# 138  0.563377
# 144  0.549496
# 150  0.535957
# 156  0.522751
# 162  0.509871
# 168  0.497308
# 174  0.485055
# 180  0.473103
