# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
x = np.linspace(0, 10, 5000)
y = np.sin(x)

# %%
output_notebook()
p = figure()
p.circle(x, y, radius=0.01)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1475">Loading BokehJS ...</span>
#     </div>
# GlyphRenderer(id='1510', ...)

# %%
show (p)
# Out:
#   <div class="bk-root" id="76d476cb-2b4b-45e9-8e24-e1a151f55a29" data-root-id="1476"></div>

# %%
x
# Out:
# array([0.00000000e+00, 2.00040008e-04, 4.00080016e-04, ...,
#        9.99599920e-01, 9.99799960e-01, 1.00000000e+00])
